# %% [markdown]
# # DBRepo: Table create and data import notebook

# %%
import requests
import os
from dotenv import load_dotenv
from requests.auth import HTTPBasicAuth

load_dotenv()

BASE_URL    = "https://test.dbrepo.tuwien.ac.at"
DATABASE_ID = "82c19b39-246c-4409-b25c-8baf3a158a70"
USERNAME = os.getenv("DBREPO_USERNAME")
PASSWORD = os.getenv("DBREPO_PASSWORD") # asks securely so password is not revealed in the code

# %%
response = requests.get(
    f"{BASE_URL}/api/v1/database/{DATABASE_ID}",
    auth=HTTPBasicAuth(USERNAME, PASSWORD),
    headers={"Accept": "application/json"}
)

if response.status_code == 200:
    db = response.json()
    print(f"Connection successful")
    print(f"Database name : {db.get('name')}")
    print(f"Database ID   : {db.get('id')}")
else:
    print(f"Connection failed with status {response.status_code}")
    print(response.text[:200])
# Out:
# Connection successful
# Database name : uk-collision-severity-prediction-main
# Database ID   : 82c19b39-246c-4409-b25c-8baf3a158a70

# %% [markdown]
# Generate Main Collisions Table

# %% [markdown]
# Create main data table

# %%
collisions_table = {
    "name": "collisions",
    "columns": [
        {"name": "collision_index",                            "type": "varchar", "size": 255, "null_allowed": False},
        {"name": "collision_year",                             "type": "int",     "null_allowed": True},
        {"name": "collision_ref_no",                          "type": "varchar", "size": 255, "null_allowed": True},
        {"name": "location_easting_osgr",                     "type": "int",     "null_allowed": True},
        {"name": "location_northing_osgr",                    "type": "int",     "null_allowed": True},
        {"name": "longitude",                                  "type": "float",   "null_allowed": True},
        {"name": "latitude",                                   "type": "float",   "null_allowed": True},
        {"name": "lsoa_of_accident_location",                 "type": "varchar", "size": 255, "null_allowed": True},
        {"name": "number_of_vehicles",                        "type": "int",     "null_allowed": True},
        {"name": "number_of_casualties",                      "type": "int",     "null_allowed": True},
        {"name": "date",                                       "type": "varchar", "size": 255, "null_allowed": True},
        {"name": "time",                                       "type": "varchar", "size": 255, "null_allowed": True},
        {"name": "day_of_week",                               "type": "int",     "null_allowed": True},
        {"name": "collision_severity",                        "type": "int",     "null_allowed": True},
        {"name": "enhanced_severity_collision",               "type": "int",     "null_allowed": True},
        {"name": "collision_injury_based",                    "type": "int",     "null_allowed": True},
        {"name": "collision_adjusted_severity_serious",       "type": "float",   "null_allowed": True},
        {"name": "first_road_number",                         "type": "int",     "null_allowed": True},
        {"name": "first_road_class",                          "type": "int",     "null_allowed": True},
        {"name": "second_road_number",                        "type": "int",     "null_allowed": True},
        {"name": "second_road_class",                         "type": "int",     "null_allowed": True},
        {"name": "road_type",                                 "type": "int",     "null_allowed": True},
        {"name": "speed_limit",                               "type": "int",     "null_allowed": True},
        {"name": "trunk_road_flag",                           "type": "int",     "null_allowed": True},
        {"name": "urban_or_rural_id",                         "type": "int",     "null_allowed": True},
        {"name": "junction_detail",                           "type": "int",     "null_allowed": True},
        {"name": "junction_control",                          "type": "int",     "null_allowed": True},
        {"name": "pedestrian_crossing",                       "type": "int",     "null_allowed": True},
        {"name": "light_conditions",                          "type": "int",     "null_allowed": True},
        {"name": "weather_conditions",                        "type": "int",     "null_allowed": True},
        {"name": "road_surface_conditions",                   "type": "int",     "null_allowed": True},
        {"name": "special_conditions_at_site",                "type": "int",     "null_allowed": True},
        {"name": "carriageway_hazards",                       "type": "int",     "null_allowed": True},
        {"name": "police_force",                              "type": "int",     "null_allowed": True},
        {"name": "did_police_officer_attend_scene_of_accident", "type": "int",  "null_allowed": True},
        {"name": "local_authority_district",                  "type": "int",     "null_allowed": True},
        {"name": "local_authority_ons_district",              "type": "varchar", "size": 255,  "null_allowed": True},
        {"name": "local_authority_highway",                   "type": "varchar", "size": 255,  "null_allowed": True},
        {"name": "local_authority_highway_current",           "type": "varchar", "size": 255,  "null_allowed": True},
    ],
    "constraints": {
        "uniques": [["collision_index"]],
        "primary_key": ["collision_index"],
        "foreign_keys": [
            {
                "columns": ["day_of_week"],
                "referenced_table": "day_of_week",
                "referenced_columns": ["dow_id"],
                "on_update": "no_action",
                "on_delete": "no_action"
            },
            {
                "columns": ["collision_severity"],
                "referenced_table": "collision_severity",
                "referenced_columns": ["collision_severity"],
                "on_update": "no_action",
                "on_delete": "no_action"
            },
            {
                "columns": ["enhanced_severity_collision"],
                "referenced_table": "enhanced_collision_severity",
                "referenced_columns": ["enhanced_collision_severity"],
                "on_update": "no_action",
                "on_delete": "no_action"
            },
            {
                "columns": ["first_road_class"],
                "referenced_table": "road_class",
                "referenced_columns": ["road_class_id"],
                "on_update": "no_action",
                "on_delete": "no_action"
            },
            {
                "columns": ["second_road_class"],
                "referenced_table": "road_class",
                "referenced_columns": ["road_class_id"],
                "on_update": "no_action",
                "on_delete": "no_action"
            },
            {
                "columns": ["road_type"],
                "referenced_table": "road_type",
                "referenced_columns": ["road_type"],
                "on_update": "no_action",
                "on_delete": "no_action"
            },
            {
                "columns": ["trunk_road_flag"],
                "referenced_table": "trunk_road_flag",
                "referenced_columns": ["trunk_road_flag"],
                "on_update": "no_action",
                "on_delete": "no_action"
            },
            {
                "columns": ["junction_detail"],
                "referenced_table": "junction_detail",
                "referenced_columns": ["junction_detail_id"],
                "on_update": "no_action",
                "on_delete": "no_action"
            },
            {
                "columns": ["junction_control"],
                "referenced_table": "junction_control",
                "referenced_columns": ["junction_control"],
                "on_update": "no_action",
                "on_delete": "no_action"
            },
            {
                "columns": ["pedestrian_crossing"],
                "referenced_table": "pedestrian_crossing",
                "referenced_columns": ["pedestrian_crossing"],
                "on_update": "no_action",
                "on_delete": "no_action"
            },
            {
                "columns": ["light_conditions"],
                "referenced_table": "light_conditions",
                "referenced_columns": ["light_conditions"],
                "on_update": "no_action",
                "on_delete": "no_action"
            },
            {
                "columns": ["weather_conditions"],
                "referenced_table": "weather_conditions",
                "referenced_columns": ["weather_conditions"],
                "on_update": "no_action",
                "on_delete": "no_action"
            },
            {
                "columns": ["road_surface_conditions"],
                "referenced_table": "road_surface_conditions",
                "referenced_columns": ["road_surface_conditions"],
                "on_update": "no_action",
                "on_delete": "no_action"
            },
            {
                "columns": ["special_conditions_at_site"],
                "referenced_table": "special_conditions_at_site",
                "referenced_columns": ["special_conditions_at_site"],
                "on_update": "no_action",
                "on_delete": "no_action"
            },
            {
                "columns": ["did_police_officer_attend_scene_of_accident"],
                "referenced_table": "did_police_attend",
                "referenced_columns": ["did_police_attend"],
                "on_update": "no_action",
                "on_delete": "no_action"
            },
            {
                "columns": ["local_authority_district"],
                "referenced_table": "local_authority_district",
                "referenced_columns": ["local_authority_district"],
                "on_update": "no_action",
                "on_delete": "no_action"
            },
            {
                "columns": ["local_authority_ons_district"],
                "referenced_table": "local_authority_ons_district",
                "referenced_columns": ["local_authority_ons_district"],
                "on_update": "no_action",
                "on_delete": "no_action"
            },
            {
                "columns": ["local_authority_highway"],
                "referenced_table": "local_authority_highway",
                "referenced_columns": ["local_authority_highway"],
                "on_update": "no_action",
                "on_delete": "no_action"
            },
            {
                "columns": ["urban_or_rural_id"],
                "referenced_table": "urban_or_rural",
                "referenced_columns": ["urban_or_rural_id"],
                "on_update": "no_action",
                "on_delete": "no_action"
            }
        ]
    },
    "is_public": False,
    "is_schema_public": False
}

response = requests.post(
    f"{BASE_URL}/api/v1/database/{DATABASE_ID}/table",
    auth=HTTPBasicAuth(USERNAME, PASSWORD),
    headers={
        "Content-Type": "application/json",
        "Accept": "application/json"
    },
    json=collisions_table
    )
print(response.text)
# Out:
# {"id":"a5b0155a-9fc6-48f6-8b24-1f591dbf5cad","name":"collisions","description":null,"database_id":"82c19b39-246c-4409-b25c-8baf3a158a70","internal_name":"collisions","is_versioned":true,"is_public":false,"is_schema_public":false,"owned_by":"12550259"}

# %% [markdown]
# Generate Lookup Tables

# %%
table = {
    "name": "collision_severity",
    "columns": [
        {"name": "collision_severity", "type": "int",     "null_allowed": False},
        {"name": "label",              "type": "varchar", "size": 255, "null_allowed": True},
    ],
    "constraints": {
        "uniques": [["collision_severity"]],
        "primary_key": ["collision_severity"]
    },
    "is_public": False,
    "is_schema_public": False
}

response = requests.post(
    f"{BASE_URL}/api/v1/database/{DATABASE_ID}/table",
    auth=HTTPBasicAuth(USERNAME, PASSWORD),
    headers={
        "Content-Type": "application/json",
        "Accept": "application/json"
    },
    json=table
    )
print(response.text)
# Out:
# {"timestamp":"2026-05-19T17:20:18.997+00:00","status":500,"error":"Internal Server Error","path":"/api/v1/database/82c19b39-246c-4409-b25c-8baf3a158a70/table"}

# %%
collision_severity_table = {
    "name": "collision_severity",
    "columns": [
        {"name": "collision_severity", "type": "int",     "null_allowed": False},
        {"name": "label",              "type": "varchar", "size": 255, "null_allowed": True},
    ],
    "constraints": {
        "foreign_keys": [],
        "uniques": [["collision_severity"]],
        "primary_key": ["collision_severity"]
    },
    "is_public": False,
    "is_schema_public": False
}
 
enhanced_collision_severity_table = {
    "name": "enhanced_collision_severity",
    "columns": [
        {"name": "enhanced_collision_severity", "type": "int",     "null_allowed": False},
        {"name": "label",                       "type": "varchar", "size": 255, "null_allowed": True},
    ],
    "constraints": {
        "foreign_keys": [],
        "uniques": [["enhanced_collision_severity"]],
        "primary_key": ["enhanced_collision_severity"]
    },
    "is_public": False,
    "is_schema_public": False
}
 
did_police_attend_table = {
    "name": "did_police_attend",
    "columns": [
        {"name": "did_police_attend", "type": "int",     "null_allowed": False},
        {"name": "label",             "type": "varchar", "size": 255, "null_allowed": True},
    ],
    "constraints": {
        "foreign_keys": [],
        "uniques": [["did_police_attend"]],
        "primary_key": ["did_police_attend"]
    },
    "is_public": False,
    "is_schema_public": False
}
 
day_of_week_table = {
    "name": "day_of_week",
    "columns": [
        {"name": "dow_id",       "type": "int",     "null_allowed": False},
        {"name": "day_of_week",  "type": "varchar", "size": 50,  "null_allowed": True},
    ],
    "constraints": {
        "foreign_keys": [],
        "uniques": [["dow_id"]],
        "primary_key": ["dow_id"]
    },
    "is_public": False,
    "is_schema_public": False
}
 
junction_control_table = {
    "name": "junction_control",
    "columns": [
        {"name": "junction_control", "type": "int",     "null_allowed": False},
        {"name": "label",            "type": "varchar", "size": 255, "null_allowed": True},
    ],
    "constraints": {
        "foreign_keys": [],
        "uniques": [["junction_control"]],
        "primary_key": ["junction_control"]
    },
    "is_public": False,
    "is_schema_public": False
}
 
junction_detail_table = {
    "name": "junction_detail",
    "columns": [
        {"name": "junction_detail_id", "type": "int",     "null_allowed": False},
        {"name": "label",              "type": "varchar", "size": 255, "null_allowed": True},
    ],
    "constraints": {
        "foreign_keys": [],
        "uniques": [["junction_detail_id"]],
        "primary_key": ["junction_detail_id"]
    },
    "is_public": False,
    "is_schema_public": False
}
 
light_conditions_table = {
    "name": "light_conditions",
    "columns": [
        {"name": "light_conditions", "type": "int",     "null_allowed": False},
        {"name": "label",            "type": "varchar", "size": 255, "null_allowed": True},
    ],
    "constraints": {
        "foreign_keys": [],
        "uniques": [["light_conditions"]],
        "primary_key": ["light_conditions"]
    },
    "is_public": False,
    "is_schema_public": False
}
 
pedestrian_crossing_table = {
    "name": "pedestrian_crossing",
    "columns": [
        {"name": "pedestrian_crossing", "type": "int",     "null_allowed": False},
        {"name": "label",               "type": "varchar", "size": 255, "null_allowed": True},
    ],
    "constraints": {
        "foreign_keys": [],
        "uniques": [["pedestrian_crossing"]],
        "primary_key": ["pedestrian_crossing"]
    },
    "is_public": False,
    "is_schema_public": False
}
 
road_class_table = {
    "name": "road_class",
    "columns": [
        {"name": "road_class_id",    "type": "int",     "null_allowed": False},
        {"name": "road_class_label", "type": "varchar", "size": 255, "null_allowed": True},
    ],
    "constraints": {
        "foreign_keys": [],
        "uniques": [["road_class_id"]],
        "primary_key": ["road_class_id"]
    },
    "is_public": False,
    "is_schema_public": False
}
 
road_surface_conditions_table = {
    "name": "road_surface_conditions",
    "columns": [
        {"name": "road_surface_conditions", "type": "int",     "null_allowed": False},
        {"name": "label",                   "type": "varchar", "size": 255, "null_allowed": True},
    ],
    "constraints": {
        "foreign_keys": [],
        "uniques": [["road_surface_conditions"]],
        "primary_key": ["road_surface_conditions"]
    },
    "is_public": False,
    "is_schema_public": False
}
 
road_type_table = {
    "name": "road_type",
    "columns": [
        {"name": "road_type",  "type": "int",     "null_allowed": False},
        {"name": "road_label", "type": "varchar", "size": 255, "null_allowed": True},
    ],
    "constraints": {
        "foreign_keys": [],
        "uniques": [["road_type"]],
        "primary_key": ["road_type"]
    },
    "is_public": False,
    "is_schema_public": False
}
 
special_conditions_at_site_table = {
    "name": "special_conditions_at_site",
    "columns": [
        {"name": "special_conditions_at_site", "type": "int",     "null_allowed": False},
        {"name": "label",                      "type": "varchar", "size": 255, "null_allowed": True},
    ],
    "constraints": {
        "foreign_keys": [],
        "uniques": [["special_conditions_at_site"]],
        "primary_key": ["special_conditions_at_site"]
    },
    "is_public": False,
    "is_schema_public": False
}
 
trunk_road_flag_table = {
    "name": "trunk_road_flag",
    "columns": [
        {"name": "trunk_road_flag", "type": "int",     "null_allowed": False},
        {"name": "label",          "type": "varchar", "size": 255, "null_allowed": True},
    ],
    "constraints": {
        "foreign_keys": [],
        "uniques": [["trunk_road_flag"]],
        "primary_key": ["trunk_road_flag"]
    },
    "is_public": False,
    "is_schema_public": False
}
 
weather_conditions_table = {
    "name": "weather_conditions",
    "columns": [
        {"name": "weather_conditions", "type": "int",     "null_allowed": False},
        {"name": "label",             "type": "varchar", "size": 255, "null_allowed": True},
    ],
    "constraints": {
        "foreign_keys": [],
        "uniques": [["weather_conditions"]],
        "primary_key": ["weather_conditions"]
    },
    "is_public": False,
    "is_schema_public": False
}
 
local_authority_district_table = {
    "name": "local_authority_district",
    "columns": [
        {"name": "local_authority_district", "type": "int",     "null_allowed": False},
        {"name": "label",                    "type": "varchar", "size": 255, "null_allowed": True},
    ],
    "constraints": {
        "foreign_keys": [],
        "uniques": [["local_authority_district"]],
        "primary_key": ["local_authority_district"]
    },
    "is_public": False,
    "is_schema_public": False
}
 
local_authority_ons_district_table = {
    "name": "local_authority_ons_district",
    "columns": [
        {"name": "local_authority_ons_district", "type": "varchar", "size": 50,  "null_allowed": False},
        {"name": "label",                        "type": "varchar", "size": 255, "null_allowed": True},
    ],
    "constraints": {
        "foreign_keys": [],
        "uniques": [["local_authority_ons_district"]],
        "primary_key": ["local_authority_ons_district"]
    },
    "is_public": False,
    "is_schema_public": False
}
 
local_authority_highway_table = {
    "name": "local_authority_highway",
    "columns": [
        {"name": "local_authority_highway", "type": "varchar", "size": 50,  "null_allowed": False},
        {"name": "label",                   "type": "varchar", "size": 255, "null_allowed": True},
    ],
    "constraints": {
        "foreign_keys": [],
        "uniques": [["local_authority_highway"]],
        "primary_key": ["local_authority_highway"]
    },
    "is_public": False,
    "is_schema_public": False
}

urban_or_rural = {
    "name": "urban_or_rural",
    "columns": [
        {"name": "urban_or_rural_id", "type": "int",  "null_allowed": False},
        {"name": "label",                   "type": "varchar", "size": 255, "null_allowed": True},
    ],
    "constraints": {
        "foreign_keys": [],
        "uniques": [["urban_or_rural_id"]],
        "primary_key": ["urban_or_rural_id"]
    },
    "is_public": False,
    "is_schema_public": False
}

LOOKUP_TABLES = [
    collision_severity_table,
    enhanced_collision_severity_table,
    did_police_attend_table,
    day_of_week_table,
    junction_control_table,
    junction_detail_table,
    light_conditions_table,
    pedestrian_crossing_table,
    road_class_table,
    road_surface_conditions_table,
    road_type_table,
    special_conditions_at_site_table,
    trunk_road_flag_table,
    weather_conditions_table,
    local_authority_district_table,
    local_authority_ons_district_table,
    local_authority_highway_table,
    urban_or_rural
]

for table in LOOKUP_TABLES:
        response = requests.post(
        f"{BASE_URL}/api/v1/database/{DATABASE_ID}/table",
        auth=HTTPBasicAuth(USERNAME, PASSWORD),
        headers={
            "Content-Type": "application/json",
            "Accept": "application/json"
        },
        json=table
        )
        print(response.text)
# Out:
# {"status":"CONFLICT","message":"Failed to create table: already exists: 409  on POST request for \"http://data-service/api/v1/database/82c19b39-246c-4409-b25c-8baf3a158a70/table\": \"{\"status\":\"CONFLICT\",\"message\":\"Failed to create table: already exists: (conn=909678) Table 'collision_severity' already exists\",\"code\":\"error.table.exists\"}\"","code":"error.table.exists"}
# {"status":"CONFLICT","message":"Failed to create table: already exists: 409  on POST request for \"http://data-service/api/v1/database/82c19b39-246c-4409-b25c-8baf3a158a70/table\": \"{\"status\":\"CONFLICT\",\"message\":\"Failed to create table: already exists: (conn=840308) Table 'enhanced_collision_severity' already exists\",\"code\":\"error.table.exists\"}\"","code":"error.table.exists"}
# ...

# %% [markdown]
# Data Guide Table Create

# %%
table ={
    "name": "Data_Guide",
    "columns": [
        {"name": "field_name", "type": "varchar", "size": 255, "null_allowed": False},
        {"name" : "code_format", "type" : "varchar","size": 255, "null_allowed" : True},
        {"name" : "label", "type" : "varchar","size": 255, "null_allowed" : True},
        {"name" : "note", "type" : "varchar","size": 255, "null_allowed" : True},

        ],
    "constraints": {
        "foreign_keys": [],
        "uniques": [["field_name"]],
        "primary_key": ["collision_index"]
    },
    "is_public": False,
    "is_schema_public": False
}
response = requests.post(
        f"{BASE_URL}/api/v1/database/{DATABASE_ID}/table",
        auth=HTTPBasicAuth(USERNAME, PASSWORD),
        headers={
            "Content-Type": "application/json",
            "Accept": "application/json"
        },
        json=table
        )
print(response.text)

# %%
response = requests.get(
        f"{BASE_URL}/api/v1/database/{DATABASE_ID}/table",
        auth=HTTPBasicAuth(USERNAME, PASSWORD),
        headers={
            "Content-Type": "application/json",
            "Accept": "application/json"
        },
        json=table
        )
print(response.text)
# Out:
# [{"id":"15b01716-5a05-480a-8554-df641e159301","name":"collisions","description":null,"database_id":"82c19b39-246c-4409-b25c-8baf3a158a70","internal_name":"collisions","is_versioned":true,"is_public":false,"is_schema_public":false,"owned_by":"12550259"},{"id":"ea064086-03ef-4c17-a15f-ec533ba77799","name":"local_authority_highway","description":null,"database_id":"82c19b39-246c-4409-b25c-8baf3a158a70","internal_name":"local_authority_highway","is_versioned":true,"is_public":false,"is_schema_public":false,"owned_by":"12550259"},{"id":"83ff3a0a-4298-4aa8-9691-caf479242462","name":"local_authority_ons_district","description":null,"database_id":"82c19b39-246c-4409-b25c-8baf3a158a70","internal_name":"local_authority_ons_district","is_versioned":true,"is_public":false,"is_schema_public":false,"owned_by":"12550259"},{"id":"d6ad4357-fe53-4542-861e-c4073d2a0142","name":"local_authority_district","description":null,"database_id":"82c19b39-246c-4409-b25c-8baf3a158a70","internal_name":"local_autho
# ...
